# %%
import pandas as pd
import seaborn as se
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the dataset into pandas dataframe

# %%
data = pd.read_csv('train.csv')

# %% [markdown]
# Displaying the entries

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Checking the frequency of each passenger class

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# Bar Graph for number of males, females and mean of fare

# %%
res = data['Sex'].value_counts()

titles = ["Male", "Female", "Mean of Fare"]
vals = [res[0], res[1], data["Fare"].mean()]

plt.bar(titles, vals)
plt.show()

# %% [markdown]
# Line chart

# %%
data.iloc[50:100].dropna().plot(kind = 'line', x = 'PassengerId',y = 'Fare')
plt.show()

# %% [markdown]
# Line chart for multiple values

# %%
ax = plt.gca()
data.iloc[0:21].dropna().plot(kind = 'line',x = 'Name',y = 'Age',color = 'blue',ax = ax)
data.iloc[0:21].dropna().plot(kind = 'line',x = 'Name',y = 'Fare',color = 'Red',ax = ax)
plt.figure(figsize = (100,200))
plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(data['Age'],bins = 8,color = 'green',edgecolor = 'black')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Boxplot

# %%
bpl = data.boxplot(column=['Age','Fare','Pclass'])

bpl.plot()
plt.show()

# %% [markdown]
# Scatter Plot

# %%
plt.scatter(data['Age'],data['Fare'],color='red')
plt.show()

# %% [markdown]
# Scatter plot 3D

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data['Age'], data['Fare'], color = 'blue')

plt.show()

# %%
series_class = pd.Series(data.Pclass)
series_class
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
se.scatterplot(data=data, x='Pclass')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-005c2dac263b> in <module>
# ----> 1 se.scatterplot(data=data, x='Pclass')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1388                 legend="brief", ax=None, **kwargs):
#    1389
# -> 1390     p = _ScatterPlotter(
#    1391         x=x, y=y, hue=hue, style=style, size=size, data=data,
#    1392         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ...

# %% [markdown]
# Boxplot

# %%
se.boxplot(data['Fare'])

# %%
se.boxplot(data['Age'])

# %% [markdown]
# Violin Plot

# %%
se.violinplot(y=data['Age'])

# %% [markdown]
# Kdeplot

# %%
se.kdeplot(y=data['Fare'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-4598b87c9ac7> in <module>
# ----> 1 se.kdeplot(y=data['Fare'])
#
# TypeError: kdeplot() missing 1 required positional argument: 'data'
